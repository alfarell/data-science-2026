# %% [markdown]
# Nama  : Alfarell Muchamad Yuwanto
#
# NIM   : 240401010037
#
# Kelas : IF401

# %% [markdown]
# # Hands On Pertemuan 1 - Notebook Pertama

# %% [markdown]
# ## Output sederhana

# %%
print("Hello, Data Science!")
print("Selamat datang di mata kuliah Pengantar Data Science!")
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science!

# %% [markdown]
# ## Variabel dan tipe data dasar

# %%
nama = "Alfarell Muchamad Yuwanto" # String
angkatan = 2024 # Integer
ipk = 3.70 # Float
aktif = True # Boolean

print(f"Nama : {nama}")
print(f"Angkatan: {angkatan}")
print(f"IPK : {ipk}")
print(f"Aktif : {aktif}")
# Out:
# Nama : Alfarell Muchamad Yuwanto
# Angkatan: 2024
# IPK : 3.7
# Aktif : True

# %% [markdown]
# ## List dan perulangan

# %%
tools = ["Python", "Google Colab", "Jupyter Notebook", "GitHub"]
print("\nTools Data Science yang akan kita pelajari:")
for i, tool in enumerate(tools, 1):
  print(f" {i}. {tool}")
# Out:
# Tools Data Science yang akan kita pelajari:
#  1. Python
#  2. Google Colab
#  3. Jupyter Notebook
#  4. GitHub

# %% [markdown]
# ## Fungsi sederhana

# %%
def perkenalan(nama, prodi, angkatan):
  """Fungsi untuk menampilkan perkenalan mahasiswa."""
  return f"Hai! Saya {nama} dari {prodi}, angkatan {angkatan}."

hasil = perkenalan("Alfarell Muchamad Yuwanto", "Informatika", 2024)
print(hasil)
# Out:
# Hai! Saya Alfarell Muchamad Yuwanto dari Informatika, angkatan 2024.

# %% [markdown]
# ## Kesimpulan
#
# - **Apa yang dipelajari:** Dasar pemrograman Python (variabel, tipe data, list, perulangan, fungsi) dan cara menjalankan kode interaktif di notebook.
# - **Temuan utama:** Mampu membuat fungsi sederhana, menggunakan perulangan dan struktur data dasar untuk menyelesaikan tugas kecil.
# - **Keterbatasan / Pertanyaan:** Perlu latihan lebih pada penanganan error, penulisan fungsi yang modular, dan penggunaan modul/libraries untuk tugas yang mungkin lebih kompleks.
